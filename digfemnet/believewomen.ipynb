# %%
import pandas as pd
import plotly.express as px

times = pd.read_csv("/home/nruest/Projects/digfemcan/twitter-data/believewomen-times.csv")

times['created_at'] = pd.to_datetime(times['created_at'])

times['date'] = times['created_at'].dt.date

tweet_volume_by_day = times['date'].value_counts().sort_index()

fig = px.bar(
    x=tweet_volume_by_day.index,
    y=tweet_volume_by_day.values,
    labels={'x': 'Date', 'y': 'Tweet Volume'},
    title='Tweet Volume by Day',
)

fig.update_layout(
    title={
        'text': '#believewomen Tweet Volume by Day',
        'font': {
            'size': 20,
            'family': 'Arial, sans-serif',
            'color': 'black',
            'weight': 'bold'
        },
        'x': 0.5,
        'xanchor': 'center',
        'y': 0.95,
        'yanchor': 'top'
    },
    margin=dict(l=50, r=50, t=150, b=100),
    xaxis_title='Date',
    yaxis_title='Tweet Volume',
    plot_bgcolor='rgba(0,0,0,0)',
    paper_bgcolor='rgba(0,0,0,0)',
    font=dict(family="Arial, sans-serif", size=12, color="black"),
    width=1200,
    height=800,
)

fig.show()
# Out:
# /tmp/ipykernel_2482968/963389725.py:6: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# <div>                            <div id="e4a61e09-260f-45be-ace3-0f857754d167" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4a61e09-260f-45be-ace3-0f857754d167")) {                    Plotly.newPlot(                        "e4a61e09-260f-45be-ace3-0f857754d167",                        [{"alignmentgroup":"True","hovertemplate":"Date=%{x}\u003cbr\u003eTweet Volume=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2017-10-15","2017-10-16","2017-10-17","2017-10-18","2017-10-19","2017-10-20","2017-10-21","2017-10-22","2017-10-23","2017-10-24","2017-10-25","2017-10-26","2017-10-27","2017-10-28","2017-10-29","2017-10-30","2017-10-31","2017-11-01","2017-11-02","2017-11-03","2017-11-04","2017-11-05","2017-11-06","2017-11-07","2017-11-08","2017-11-09","2017-11-10","2017-11-11","2017-11-12","2017-11-13","2017-11-14","2017-11-15","2017-11-16","2017-11-17","2017-11-18","2017-11-19","2017-11-20","2017-11-21","2017-11-22","2017-11-23","2017-11-24","2017-11-25","2017-11-26","2017-11-27","2017-11-28","2017-11-29","2017-11-30","2017-12-01","2017-12-02","2017-12-03","2017-12-04","2017-12-05","2017-12-06","2017-12-07","2017-12-08","2017-12-09","2017-12-10","2017-12-11","2017-12-12","2017-12-13","2017-12-14","2017-12-15","2017-12-16","2017-12-17","2017-12-18","2017-12-19","2017-12-20","2017-12-21","2017-12-22","2017-12-23","2017-12-24","2017-12-25","2017-12-26","2017-12-27","2017-12-28","2017-12-29","2017-12-30","2017-12-31","2018-01-01","2018-01-02","2018-01-03","2018-01-04","2018-01-05","2018-01-06","2018-01-07","2018-01-08","2018-01-09","2018-01-10","2018-01-11","2018-01-12","2018-01-13","2018-01-14","2018-01-15","2018-01-16","2018-01-17","2018-01-18","2018-01-19","2018-01-20","2018-01-21","2018-01-22","2018-01-23","2018-01-24","2018-01-25","2018-01-26","2018-01-27","2018-01-28","2018-01-29","2018-01-30","2018-01-31","2018-02-01","2018-02-02","2018-02-03","2018-02-04","2018-02-05","2018-02-06","2018-02-07","2018-02-08","2018-02-09","2018-02-10","2018-02-11","2018-02-12","2018-02-13","2018-02-14","2018-02-15","2018-02-16","2018-02-17","2018-02-18","2018-02-19","2018-02-20","2018-02-21","2018-02-22","2018-02-23","2018-02-24","2018-02-25","2018-02-26","2018-02-27","2018-02-28","2018-03-01","2018-03-02","2018-03-03","2018-03-04","2018-03-05","2018-03-06","2018-03-07","2018-03-08","2018-03-09","2018-03-10","2018-03-11","2018-03-12","2018-03-13","2018-03-14","2018-03-15","2018-03-16","2018-03-17","2018-03-18","2018-03-19","2018-03-20","2018-03-21","2018-03-22","2018-03-23","2018-03-24","2018-03-25","2018-03-26","2018-03-27","2018-03-28","2018-03-29","2018-03-30","2018-03-31","2018-04-01","2018-04-02","2018-04-03","2018-04-04","2018-04-05","2018-04-06","2018-04-07","2018-04-08","2018-04-09","2018-04-10","2018-04-11","2018-04-12","2018-04-13","2018-04-14","2018-04-15","2018-04-16","2018-04-17","2018-04-18","2018-04-19","2018-04-20","2018-04-21","2018-04-22","2018-04-23","2018-04-24","2018-04-25","2018-04-26","2018-04-27","2018-04-28","2018-04-29","2018-04-30","2018-05-01","2018-05-02","2018-05-03","2018-05-04","2018-05-05","2018-05-06","2018-05-07","2018-05-08","2018-05-09","2018-05-10","2018-05-11","2018-05-12","2018-05-13","2018-05-14","2018-05-15","2018-05-16","2018-05-17","2018-05-18","2018-05-19","2018-05-20","2018-05-21","2018-05-22","2018-05-23","2018-05-24","2018-05-25","2018-05-26","2018-05-27","2018-05-28","2018-05-29","2018-05-30","2018-05-31","2018-06-01","2018-06-02","2018-06-03","2018-06-04","2018-06-05","2018-06-06","2018-06-07","2018-06-08","2018-06-09","2018-06-10","2018-06-11","2018-06-12","2018-06-13","2018-06-14","2018-06-15","2018-06-16 ...

# %%
import pandas as pd
import plotly.express as px

userInfo = pd.read_csv("/home/nruest/Projects/digfemcan/twitter-data/believewomen-user-info.csv")

tweeters = userInfo['screen_name'].value_counts().rename_axis("Username").reset_index(name="Count").head(10)

fig = px.bar(tweeters, 
             x='Username', 
             y='Count', 
             labels={'Username': 'Twitter Username', 'Count': 'Tweet Count'},
             color='Count',
             color_continuous_scale='Viridis'
            )

fig.update_layout(
    title={
        'text': 'Top 10 Twitter Users of #believewomen by Tweet Count',
        'font': {
            'size': 20,
            'family': 'Arial, sans-serif',
            'color': 'black',
            'weight': 'bold'
        },
        'x': 0.5,
        'xanchor': 'center',
        'y': 0.95,
        'yanchor': 'top'
    },
    margin=dict(l=50, r=50, t=150, b=100),
    xaxis_title='Username',
    yaxis_title='Tweet Count',
    plot_bgcolor='rgba(0,0,0,0)',
    paper_bgcolor='rgba(0,0,0,0)',
    font=dict(family="Arial, sans-serif", size=12, color="black"),
    width=1200,
    height=1000,
)

fig.show()

# %%
import pandas as pd
import plotly.express as px

hashtags = pd.read_csv("/home/nruest/Projects/digfemcan/twitter-data/believewomen-hashtags.csv")

hashtag_count = hashtags.value_counts().rename_axis("Hashtag").reset_index(name="Count").head(10)

fig = px.bar(hashtag_count, 
             x='Hashtag', 
             y='Count', 
             labels={'Hashtag': 'Hashtag', 'Count': 'Hashtag Count'},
             color='Count',
             color_continuous_scale='Viridis'
            )

fig.update_layout(
    title={
        'text': 'Top 10 Hashtags of #believewomen by Tweet Count',
        'font': {
            'size': 20,
            'family': 'Arial, sans-serif',
            'color': 'black',
            'weight': 'bold'
        },
        'x': 0.5,
        'xanchor': 'center',
        'y': 0.95,
        'yanchor': 'top'
    },
    margin=dict(l=50, r=50, t=150, b=100),
    xaxis_title='Hashtag',
    yaxis_title='Hashtag Count',
    plot_bgcolor='rgba(0,0,0,0)',
    paper_bgcolor='rgba(0,0,0,0)',
    font=dict(family="Arial, sans-serif", size=12, color="black"),
    width=1200,
    height=1000,
)

fig.show()
